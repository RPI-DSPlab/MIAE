# %%
from mia.utils.set_seed import set_seed
import os
import torch
import torchvision
import torchvision.transforms as T
from torch.utils.data import DataLoader, random_split, ConcatDataset, Dataset

# %% [markdown]
# # Point to Point Attacks Comparison Analysis
# Workflow:
# 1. Read the prediction from the Attacks
# 2. Split them to high and low FPR Samples (Where low FPR samples are the samples that's not attack able at high FPR region, and high FPR samples are hard samples that's only attack able at high FPR region)
# 3. Check the overlapping samples, the ratio of overalapping samples over non-overlapping samples
