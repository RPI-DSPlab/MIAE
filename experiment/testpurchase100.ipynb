# %%
from mia_comp.datasets import *

texas = get_texas100() # dataset is now a torch dataset
purchase = get_purchase100() # dataset is now a torch dataset

# %%
# print the number of classes, number of samples, and number of features
print(texas.n_classes, texas.n_samples, texas.n_features)
print(purchase.n_classes, purchase.n_samples, purchase.n_features)

print(texas.labels)
# Out:
# 100 60000 6169
# 100 60000 600
# [31 94 72 ... 75 98 30]
